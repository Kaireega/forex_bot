# %%
import pandas as pd

# %%
df = pd.read_pickle("../data/USD_JPY_M15.pkl")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5180 entries, 0 to 5179
# Data columns (total 14 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   time    5180 non-null   datetime64[ns, tzutc()]
#  1   volume  5180 non-null   int64
#  2   mid_o   5180 non-null   float64
#  3   mid_h   5180 non-null   float64
#  4   mid_l   5180 non-null   float64
#  5   mid_c   5180 non-null   float64
#  6   bid_o   5180 non-null   float64
#  7   bid_h   5180 non-null   float64
#  8   bid_l   5180 non-null   float64
#  9   bid_c   5180 non-null   float64
#  10  ask_o   5180 non-null   float64
#  11  ask_h   5180 non-null   float64
#  12  ask_l   5180 non-null   float64
#  13  ask_c   5180 non-null   float64
# dtypes: datetime64[ns, tzutc()](1), float64(12), int64(1)
# memory usage: 566.7 KB

# %%
df.head(192)
# Out:
#                          time  volume    mid_o    mid_h    mid_l    mid_c  \
# 0   2024-11-01 00:00:00+00:00    6005  151.981  152.142  151.922  152.074
# 1   2024-11-01 00:15:00+00:00    3928  152.073  152.169  151.982  152.070
# 2   2024-11-01 00:30:00+00:00    3025  152.070  152.138  152.020  152.044
# 3   2024-11-01 00:45:00+00:00    5998  152.044  152.064  151.876  152.034
# 4   2024-11-01 01:00:00+00:00    4583  152.036  152.097  151.962  151.986
# ..                        ...     ...      ...      ...      ...      ...
# 187 2024-11-04 23:45:00+00:00     908  152.242  152.296  152.197  152.282
# 188 2024-11-05 00:00:00+00:00    3834  152.282  152.292  152.112  152.132
# 189 2024-11-05 00:15:00+00:00    2383  152.132  152.206  152.121  152.191
# 190 2024-11-05 00:30:00+00:00    3116  152.190  152.400  152.188  152.390
# 191 2024-11-05 00:45:00+00:00    4204  152.390  152.400  152.268  152.282
#
#        bid_o    bid_h    bid_l    bid_c    ask_o    ask_h    ask_l    ask_c
# ...

# %%
# Load the .pkl file

df = pd.read_pickle("../data/USD_JPY_M15.pkl")

# Export to whole set as JSON
json_path = "USD_JPY_M15"
# df.to_json(json_path, orient="records", lines=True)
# print(f"JSON data saved to {json_path}")

# Export to chunks as JSON
chunk_size = 1000  # Number of rows per chunk
for i in range(0, len(df), chunk_size):
    chunk = df.iloc[i:i + chunk_size]
    chunk.to_json(f" USD_JPY_M15 chunk_{i // chunk_size + 1}.json", orient="records", lines=True)
    print(f"JSON data saved to {json_path}_{i // chunk_size + 1}.json")
# Out:
# JSON data saved to USD_JPY_M15_1.json
# JSON data saved to USD_JPY_M15_2.json
# JSON data saved to USD_JPY_M15_3.json
# JSON data saved to USD_JPY_M15_4.json
# JSON data saved to USD_JPY_M15_5.json
# JSON data saved to USD_JPY_M15_6.json
